# %% [markdown]
# <a href="https://colab.research.google.com/github/saathisudip/Exploratory-Data-Analysis-of-Unicorn-Companies/blob/main/Web_scarping_Unicorn_Companies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Web Scraping - Unicorn Companies**#
# data source: https://www.cbinsights.com/research-unicorn-companies

# %% [markdown]
# #Import necessary libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_url = 'https://www.cbinsights.com/research-unicorn-companies/'
page = requests.get(data_url)
content = BeautifulSoup(page.text, 'html')

# %%
content

# %%
content.find('table', class_='wikitable sortable sticky-header')

# %%
table = content.find_all('table')
print(table)

# %%
titles = content.find_all('th')

# %%
table_titles = [title.text.strip() for title in titles]

print(table_titles)
# Out:
# ['Company', 'Valuation ($B)', 'Date Joined', 'Country', 'City', 'Industry', 'Select Investors']

# %%
#create an empty DataFrame to contain data
df = pd.DataFrame(columns = table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Company, Valuation ($B), Date Joined, Country, City, Industry, Select Investors]
# Index: []

# %%
column_data = content.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    company_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = company_data

# %%
df
# Out:
#                   Company Valuation ($B) Date Joined        Country  \
# 0               ByteDance           $225    4/7/2017          China
# 1                  SpaceX           $150   12/1/2012  United States
# 2                   SHEIN            $66    7/3/2018      Singapore
# 3                  Stripe            $50   1/23/2014  United States
# 4              Databricks            $43    2/5/2019  United States
# ...                   ...            ...         ...            ...
# 1225          LeadSquared             $1   6/21/2022          India
# 1226            FourKites             $1   6/21/2022  United States
# 1227          VulcanForms             $1    7/5/2022  United States
# 1228          SingleStore             $1   7/12/2022  United States
# 1229  Unstoppable Domains             $1   7/27/2022  United States
#
#                City               Industry  \
# 0           Beijing  Media & Entertainment
# 1         Hawthorne            Industrials
# ...

# %%
#export the dataframe to a csv file
df.to_csv(r'../content/Unicorn_company.csv', index = False)
